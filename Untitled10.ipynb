# %%
print("thiru")
# Out:
# thiru

# %%
''' calculations'''

print(2+5)
print(2-5)
print(2*5)
print(2%5)
# Out:
# 7
# -3
# 10
# 2

# %%
''' assiging variables'''

a="thiru"
b="loves"
c="python"
print(a+"  "+b+"  "+c)
# Out:
# thiru  loves  python

# %%
'''taking input from user'''

a=input("enter yuor name: ")
# Out:
# enter yuor name: thiru

# %%
'''quations'''
print("thiru")
# Out:
# thiru

# %%
print(25+35)
# Out:
# 60

# %%
''' variables==to store the value is called variable'''

a="nihar"
b="thiru"
print(a)
print(b)
# Out:
# nihar
# thiru

# %%
'''data types==string(str),integer(int),floot,boolean'''
int=47
print(int)
# Out:
# 47

# %%
floot=25.5
print(floot)
# Out:
# 25.5

# %%
import string
string="thiru"
print(string)
# Out:
# thiru

# %%
from traitlets.config.application import T
is_true= True
is_false=False
print(is_true)
print(is_false)
# Out:
# True
# False

# %%
'''questions'''
a=20
b=30
print (a+b)
# Out:
# 50

# %%
king="thiru"
