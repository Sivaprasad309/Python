# %% [markdown]
# amstrong num or not

# %%
if sum==120:
  print(sum,"is an amstrong")
else:
  print(sum,"is not an amstrong number")
# Out:
# <built-in function sum> is not an amstrong number

# %% [markdown]
# 1.using while loop

# %%
num=2
while num<10:
  print(num)
  num+=2
# Out:
# 2
# 4
# 6
# 8

# %%
num=3
while num<20:
  print(num)
  num+=2
# Out:
# 3
# 5
# 7
# 9
# 11
# 13
# 15
# 17
# 19

# %%
num=1
while num<=6:
  print(num)
  num+=1
# Out:
# 1
# 2
# 3
# 4
# 5
# 6

# %%
num=0
while num<=5:
  print(num)
  num+=1
# Out:
# 0
# 1
# 2
# 3
# 4
# 5

# %% [markdown]
# 2.integers

# %%
num=1
while num<=12:
  square=num*num
  print('{} {}'.format(num,square))
  num+=1
# Out:
# 1 1
# 2 4
# 3 9
# 4 16
# 5 25
# 6 36
# 7 49
# 8 64
# 9 81
# 10 100
# 11 121
# 12 144

# %%
num=102
while num>0:
  print(num)
  num-=6
# Out:
# 102
# 96
# 90
# 84
# 78
# 72
# 66
# 60
# 54
# 48
# 42
# 36
# 30
# 24
# 18
# 12
# 6

# %%
i=5
j=1
while i==5:
  while j<=10:
    print('{}*{}={}'.format(i,j,i*j))
    j+=1
    break
# Out:
# 5*1=5
# 5*2=10
# 5*3=15
# 5*4=20
# 5*5=25
# 5*6=30
# 5*7=35
# 5*8=40
# 5*9=45
# 5*10=50
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-86-272365c33ac7> in <cell line: 3>()
#       1 i=5
#       2 j=1
# ----> 3 while i==5:
#       4   while j<=10:
#       5     print('{}*{}={}'.format(i,j,i*j))
#
# KeyboardInterrupt:

# %%
num=int(input("enter num:"))
a=5
b=5
for i in range(2,num+2):
  c=a+b
  a=b
  b=c
  print(c,end=" ")
# Out:
# enter num:10
# 10 15 25 40 65 105 170 275 445 720

# %%
num=10
num1=20
for i in range(3,num+3):
  num2=num1+num
  num=num1
  num1=num2
  print(num2,end=" ")
# Out:
# 30 50 80 130 210 340 550 890 1440 2330

# %%
year=int(input("enter a leap year:"))
if (year%100==0) and (year%400==0):
  print("a is a leap year")
elif (year%100==0) and (year%100!=0):
  print("a is a leap year")
else:
  print("a is not a leap year")
# Out:
# enter a leap year:2020
# a is not a leap year
