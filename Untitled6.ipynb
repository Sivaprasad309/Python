# %%
a=int(input("enter a num"))
num=a
sum=0
while a>0:
  rem=a%10
  sum=sum+rem
  a=a//10

if (num%sum==0):
  print('a harshad num')
else:
  print('not a harshad num')
# Out:
# enter a num33
# not a harshad num

# %%
a=int(input())
dict1={1:1,2:2,2:2,5:8}
dict1.pop(2)
print(dict1)
# Out:
# 1
# {1: 1, 5: 8}

# %%
dict1={2:5,6:6,'army':77}
dict1.keys()
# Out:
# dict_keys([2, 6, 'army'])

# %%
def getlist(dict1):
  return [*dict1]
dict1={2:'siva',5:'mahesh','ravi':7}
print(getlist(dict1) )
# Out:
# [2, 5, 'ravi']

# %%
a={55:66,57:66,90:230}
dict1=max(a)
print(dict1)
# Out:
# 90

# %%
def fun():
  a=10
  b=30
print(a,b)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-70-a22601570f19> in <cell line: 4>()
#       2   a=10
#       3   b=30
# ----> 4 print(a,b)
#
# NameError: name 'b' is not defined
